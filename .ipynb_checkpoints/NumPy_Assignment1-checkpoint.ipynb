# %%
import numpy as np

# %% [markdown]
# ## Q#1: Create x array with elements equal to 1.

# %%
x=np.ones((2, 2))
x
# Out:
# array([[1., 1.],
#        [1., 1.]])

# %% [markdown]
# ## Q#2: Create y array with elements equal to 0.

# %%
y=np.zeros((2, 2))
y
# Out:
# array([[0., 0.],
#        [0., 0.]])

# %% [markdown]
# ## Q#3: Add x and y arrays.

# %%
x+y
# Out:
# array([[1., 1.],
#        [1., 1.]])

# %% [markdown]
# ## Q#4: Print x array characteristics (e.g: dimension, shape, size, type).

# %%
print(x.ndim)
print(x.shape)
print(x.size)
print(x.dtype)
# Out:
# 2
# (2, 2)
# 4
# float64

# %% [markdown]
# ## Q5: Create a 2D array "called w" as the following:
#
# |       |          |
# | ----- | -------- |
# | 11    | 12       |
# | 13    | 14       |
# | 15    | 16       |

# %%
w= np.array([[11,12],[13,14],[15,16]])
w
# Out:
# array([[11, 12],
#        [13, 14],
#        [15, 16]])

# %% [markdown]
# ## Q#6: Create z array contains the numbers from 1 to 3.

# %%
z= np.array([[1], [2], [3]])
#or
# z= np.array([1, 2, 3])
# z=z.reshape(3, 1)
z
# Out:
# array([[1],
#        [2],
#        [3]])

# %% [markdown]
# ## Q#7: Combine the arrays z and w in horizontal way then save it in a new variable "newArray".

# %%
newArray = np.hstack((w,z))
newArray
# Out:
# array([[11, 12,  1],
#        [13, 14,  2],
#        [15, 16,  3]])

# %% [markdown]
# ## Q#8: Print all elements of "newArray" using the loop.

# %%
for row in newArray:
    for item in row:
        print(item)
# Out:
# 11
# 12
# 1
# 13
# 14
# 2
# 15
# 16
# 3

# %% [markdown]
# ## Q#9: Reverse the columns and rows of "newArray".

# %%
newArray.transpose()
# Out:
# array([[11, 13, 15],
#        [12, 14, 16],
#        [ 1,  2,  3]])

# %% [markdown]
# ## Q#10: Decrement all elements of "newArray" with 1.

# %%
newArray -= 1
newArray
# Out:
# array([[10, 11,  0],
#        [12, 13,  1],
#        [14, 15,  2]])

# %% [markdown]
# ## Q#11: Find smallest and biggest values in "newArray".

# %%
print("the smallest values",newArray.min())
print("the biggest values",newArray.max())
# Out:
# the smallest values 0
# the biggest values 15

# %% [markdown]
# ## Q#12: Print the first row of "newArray" using indexing.

# %%
print(newArray[0,:])
# Out:
# [10 11  0]

# %% [markdown]
# ## Q#13: Print the number equals 12 of "newArray" using indexing.

# %%
print(newArray[1,0])
# Out:
# 12

# %% [markdown]
# ## Q#14: Print the numbers equal 0 and 13 of "newArray" using indexing.

# %%
print(newArray[0,2],newArray[1,1])
# Out:
# 0 13

# %% [markdown]
# ## Q#15: Change the shape of "newArray" to (9,1).

# %%
newArray=newArray.reshape(9, 1)
newArray
# Out:
# array([[10],
#        [11],
#        [ 0],
#        [12],
#        [13],
#        [ 1],
#        [14],
#        [15],
#        [ 2]])

# %% [markdown]
# ## Q#16: Change the shape of "newArray" to (3,2).

# %%
newArray=newArray.reshape(3, 2)
#It is impossible to distribute 9 items in this size
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[51], line 1
# ----> 1 newArray=newArray.reshape(3, 2)
#
# ValueError: cannot reshape array of size 9 into shape (3,2)

# %% [markdown]
# # Well Done 🎉
